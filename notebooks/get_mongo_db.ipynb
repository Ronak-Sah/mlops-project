# %%
import pymongo
import pandas as pd

# %%
client=pymongo.MongoClient("mongodb+srv://timepasss00133_db_user:hbEzYAdhwmeXAnFw@cluster0.gkgrk7w.mongodb.net/?appName=Cluster0")
database=client["House_Price"]
collection=database["House_Price_prediction"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client=pymongo.MongoClient("mongodb+srv://timepasss00133_db_user:hbEzYAdhwmeXAnFw@cluster0.gkgrk7w.mongodb.net/?appName=Cluster0")
#       2 database=client["House_Price"]
#       3 collection=database["House_Price_prediction"]
#
# NameError: name 'pymongo' is not defined

# %%
df=pd.DataFrame(list(collection.find()))
